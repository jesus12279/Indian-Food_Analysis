# %% [markdown]
# # Indian Food Analysis
#
# ## The main idea of this project is to analyze indian dishes based on factors such as cooking time, preparation time, ingridients, etc.
#
# ## This dataset being used is gathered by a Kaggle user. I will be leaving the link below, if you have any ideas and are looking to use the same dataset.
# ## https://www.kaggle.com/nehaprabhavalkar/indian-food-101/tasks?taskId=2180

# %% [markdown]
# ## Before anything we have to load in the dataset to get access to its contents. In order to do this we have to get all the imports in beforehand that allow us to get access and download the dataset from the link above. For this project we are gonna take a deep dive into the culture and the geo locations of the variety of indian food in order to better analyze the factors of different dishes.

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
food = pd.read_csv("indian_food.csv")

# %%
food.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255 entries, 0 to 254
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            255 non-null    object
#  1   ingredients     255 non-null    object
#  2   diet            255 non-null    object
#  3   prep_time       255 non-null    int64
#  4   cook_time       255 non-null    int64
#  5   flavor_profile  255 non-null    object
#  6   course          255 non-null    object
#  7   state           255 non-null    object
#  8   region          254 non-null    object
# dtypes: int64(2), object(7)
# memory usage: 18.1+ KB

# %%
food.sample(10)
# Out:
#                      name                                        ingredients  \
# 35                Sandesh                     Milk, sugar, saffron, cardamom
# 225            Alu Pitika        Potatoes, mustard oil, fish, green chillies
# 98         Lauki ki subji  Bottle gourd, coconut oil, garam masala, ginge...
# 127  Currivepillai sadam   Chana dal, urad dal, fresh coconut, sesame see...
# 92           Kadhi pakoda  Besan, garam masala powder, gram flour, ginger...
# 10                  Laddu                            Gram flour, ghee, sugar
# 252                Shufta  Cottage cheese, dry dates, dried rose petals, ...
# 12              Nankhatai  Refined flour, besan, ghee, powdered sugar, yo...
# 54              Kajjikaya                       Rice flour, jaggery, coconut
# 147               Papadum               Lentils, black pepper, vegetable oil
#
#                diet  prep_time  cook_time flavor_profile       course  \
# ...
